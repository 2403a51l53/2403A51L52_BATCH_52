# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a51l53/2403A51L53_BATCH_52/blob/main/lab__7_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd
 import matplotlib.pyplot as plt
 data = {
 "Year": [1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020],
 "Population": [2.53, 3.03, 3.71, 4.45, 5.32, 6.12, 6.92, 7.79]
 }
 df = pd.DataFrame(data)
 plt.figure(figsize=(10, 6))
 plt.plot(df["Year"], df["Population"], marker='o', linestyle='-', linewidth=2)
 plt.xlabel("Year")
 plt.ylabel("World Population (Billions)")
 plt.title("World Population Growth Over Decades")
 plt.grid(True)
 plt.show()
